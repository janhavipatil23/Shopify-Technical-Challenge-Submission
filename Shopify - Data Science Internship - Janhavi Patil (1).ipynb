# %% [markdown]
# # Data Science Internship Challenge

# %% [markdown]
# Name - Janhavi Patil

# %% [markdown]
# # Question 1:
#
# Given some sample data, write a program to answer the following: click here to access the required data set
#
# On Shopify, we have exactly 100 sneaker shops, and each of these shops sells only one model of shoe. We want to do    some analysis of the average order value (AOV). When we look at orders data over a 30 day window, we naively calculate an AOV of $3145.13. Given that we know these shops are selling sneakers, a relatively affordable item, something seems wrong with our analysis.
#
# a. Think about what could be going wrong with our calculation. Think about a better way to evaluate this data.
#
# b. What metric would you report for this dataset?
#
# c. What is its value?

# %% [markdown]
# # Solution 1: Implementation

# %% [markdown]
# Reading and displaying the dataset csv file

# %%
# importing required packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/Users/janhavi/Downloads'

# %% [markdown]
# Let's get some insights into data.

# %%
# reading the csv file
df = pd.read_csv("/Users/janhavi/Downloads/2019 Winter Data Science Intern Challenge Data Set - Sheet1.csv")
df.head(10)
# Out:
#    order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0         1       53      746           224            2           cash
# 1         2       92      925            90            1           cash
# 2         3       44      861           144            1           cash
# 3         4       18      935           156            1    credit_card
# 4         5       18      883           156            1    credit_card
# 5         6       58      882           138            1    credit_card
# 6         7       87      915           149            1           cash
# 7         8       22      761           292            2           cash
# 8         9       64      914           266            2          debit
# 9        10       52      788           146            1    credit_card
#
#             created_at
# 0  2017-03-13 12:36:56
# 1  2017-03-03 17:38:52
# 2   2017-03-14 4:23:56
# 3  2017-03-26 12:43:37
# 4   2017-03-01 4:35:11
# 5  2017-03-14 15:25:01
# ...

# %% [markdown]
# The describe() method returns description of the data in the DataFrame

# %%
df.describe()
# Out:
#           order_id      shop_id      user_id   order_amount  total_items
# count  5000.000000  5000.000000  5000.000000    5000.000000   5000.00000
# mean   2500.500000    50.078800   849.092400    3145.128000      8.78720
# std    1443.520003    29.006118    87.798982   41282.539349    116.32032
# min       1.000000     1.000000   607.000000      90.000000      1.00000
# 25%    1250.750000    24.000000   775.000000     163.000000      1.00000
# 50%    2500.500000    50.000000   849.000000     284.000000      2.00000
# 75%    3750.250000    75.000000   925.000000     390.000000      3.00000
# max    5000.000000   100.000000   999.000000  704000.000000   2000.00000

# %% [markdown]
# Getting basic information about the data

# %%
def all_about_my_data(df):
    print("Here is some Basic Ground Info about Data:\n")
    
    # Shape of the dataframe
    print("Number of Instances:",df.shape[0])
    print("Number of Features:",df.shape[1])
    
    # Summary Stats
    print("\nSummary Stats:")
    print(df.describe())
    
    # Checking if there are any missing values
    print("\nMissing Values:")
    print(df.isna().sum())

all_about_my_data(df)
# Out:
# Here is some Basic Ground Info about Data:
#
# Number of Instances: 5000
# Number of Features: 7
#
# Summary Stats:
#           order_id      shop_id      user_id   order_amount  total_items
# count  5000.000000  5000.000000  5000.000000    5000.000000   5000.00000
# mean   2500.500000    50.078800   849.092400    3145.128000      8.78720
# std    1443.520003    29.006118    87.798982   41282.539349    116.32032
# min       1.000000     1.000000   607.000000      90.000000      1.00000
# 25%    1250.750000    24.000000   775.000000     163.000000      1.00000
# 50%    2500.500000    50.000000   849.000000     284.000000      2.00000
# 75%    3750.250000    75.000000   925.000000     390.000000      3.00000
# max    5000.000000   100.000000   999.000000  704000.000000   2000.00000
#
# Missing Values:
# order_id          0
# shop_id           0
# user_id           0
# order_amount      0
# total_items       0
# payment_method    0
# created_at        0
# dtype: int64

# %% [markdown]
# # Observation -
#
# 1. There are 5000 rows and 7 columns for this dataset
#
# 2. In the summary stats count, mean, standard deviation, min, max and interquatile ranges are calculated
#
# 3. There are no missing values in the dataset and hence we have a clean datset

# %% [markdown]
# The info() function is used to print a concise summary of a DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        5000 non-null   int64
#  1   shop_id         5000 non-null   int64
#  2   user_id         5000 non-null   int64
#  3   order_amount    5000 non-null   int64
#  4   total_items     5000 non-null   int64
#  5   payment_method  5000 non-null   object
#  6   created_at      5000 non-null   object
# dtypes: int64(5), object(2)
# memory usage: 273.6+ KB

# %% [markdown]
# Getting the mean and median of order_amount

# %%
print('Average Order Amount:', df['order_amount'].mean(), ',',
      'Median Order Amount:', df['order_amount'].median())
# Out:
# Average Order Amount: 3145.128 , Median Order Amount: 284.0

# %% [markdown]
# Sorting the dataframe of total items in accordance with values

# %%
pd.DataFrame(df['total_items'].value_counts().sort_index())
# Out:
#       total_items
# 1            1830
# 2            1832
# 3             941
# 4             293
# 5              77
# 6               9
# 8               1
# 2000           17

# %% [markdown]
# # Observation -
#
# 1. Here people have got some (8 and below) pairs of shoes
# 2. While there are 17 transactions where 2000 shoes have been bought.
# 3. This is strange and needs to be investigated and this could possibly contibute to the high Average Order Volume.
# 4. So to check if this assumption is correct or no following code is written

# %% [markdown]
# Filtering to get information about those orders where total items is 2000

# %%
df[df['total_items']==2000]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 15          16       42      607        704000         2000    credit_card
# 60          61       42      607        704000         2000    credit_card
# 520        521       42      607        704000         2000    credit_card
# 1104      1105       42      607        704000         2000    credit_card
# 1362      1363       42      607        704000         2000    credit_card
# 1436      1437       42      607        704000         2000    credit_card
# 1562      1563       42      607        704000         2000    credit_card
# 1602      1603       42      607        704000         2000    credit_card
# 2153      2154       42      607        704000         2000    credit_card
# 2297      2298       42      607        704000         2000    credit_card
# 2835      2836       42      607        704000         2000    credit_card
# ...

# %% [markdown]
# # Observation -
#
# 1. The transaction with total_items equal to 2000 are happening at the same shop by the same customer at the same time.
# 2. There can be some fraudulent activity with the customer or something is wrong with the shop which is shop 42
#
# To check that the following code is written

# %% [markdown]
# Filtering to get information about those orders where shop ID is 42

# %%
df[df['shop_id']==42]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 15          16       42      607        704000         2000    credit_card
# 40          41       42      793           352            1    credit_card
# 60          61       42      607        704000         2000    credit_card
# 308        309       42      770           352            1    credit_card
# 409        410       42      904           704            2    credit_card
# 520        521       42      607        704000         2000    credit_card
# 834        835       42      792           352            1           cash
# 835        836       42      819           704            2           cash
# 938        939       42      808          1056            3    credit_card
# 979        980       42      744           352            1          debit
# 1104      1105       42      607        704000         2000    credit_card
# ...

# %% [markdown]
# # Observation -
#
# All transactions associated with User_id 607 are outliers
#
# So tghe following code is written to drop these values from our dataset and to re calculate mean and median to know if there is still any outlier in the data

# %%
subset_df = df[df['user_id']!=607]
subset_df.head()
# Out:
#    order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0         1       53      746           224            2           cash
# 1         2       92      925            90            1           cash
# 2         3       44      861           144            1           cash
# 3         4       18      935           156            1    credit_card
# 4         5       18      883           156            1    credit_card
#
#             created_at
# 0  2017-03-13 12:36:56
# 1  2017-03-03 17:38:52
# 2   2017-03-14 4:23:56
# 3  2017-03-26 12:43:37
# 4   2017-03-01 4:35:11

# %%
print('Average Order Amount:', subset_df['order_amount'].mean(), ',',
      'Median Order Amount:', subset_df['order_amount'].median())
# Out:
# Average Order Amount: 754.0919125025085 , Median Order Amount: 284.0

# %% [markdown]
# # Observation -
#
# 1. There is still some discripancy
# 2. So calculated the price per pair of shoes in our dataset

# %%
subset_df['price_per_item'] = subset_df['order_amount']/subset_df['total_items']
# Out:
# <ipython-input-13-6c2d5353d879>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['price_per_item'] = subset_df['order_amount']/subset_df['total_items']

# %%
pd.DataFrame(subset_df['price_per_item'].describe())
# Out:
#        price_per_item
# count      4983.00000
# mean        387.86474
# std        2446.12562
# min          90.00000
# 25%         133.00000
# 50%         153.00000
# 75%         168.00000
# max       25725.00000

# %% [markdown]
# # Observation -
#
# 1. The max value is coming to be 25725
# 2. Which is suspectful for a pair of sneakers

# %%
pd.DataFrame(subset_df['price_per_item'].value_counts().sort_index())
# Out:
#          price_per_item
# 90.0                 42
# 94.0                 55
# 101.0                42
# 111.0                40
# 112.0               124
# 114.0                59
# 116.0                58
# 117.0                77
# 118.0               118
# 122.0                50
# 127.0                52
# 128.0                93
# 129.0               142
# 130.0               150
# 131.0                97
# 132.0                46
# 133.0               151
# 134.0                86
# 136.0               105
# 138.0                59
# 140.0                55
# 142.0               197
# 144.0                39
# 145.0                92
# 146.0                89
# 147.0                53
# 148.0               101
# 149.0                52
# 153.0               256
# 154.0                54
# 155.0                42
# 156.0               197
# 158.0                94
# 160.0               206
# 161.0               101
# 162.0                48
# 163.0               122
# ...

# %% [markdown]
# # Observation -
#
# 1. Roughly all prices are below 400
# 2. Except for the last value which says 46 orders were sold for 25725$ each
# 3. This is hence an outlier

# %%
normal_orders = subset_df[subset_df['price_per_item'] < 400 ]

outlier_orders = subset_df[subset_df['price_per_item'] == 25725]

# %%
outlier_orders
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 160        161       78      990         25725            1    credit_card
# 490        491       78      936         51450            2          debit
# 493        494       78      983         51450            2           cash
# 511        512       78      967         51450            2           cash
# 617        618       78      760         51450            2           cash
# 691        692       78      878        154350            6          debit
# 1056      1057       78      800         25725            1          debit
# 1193      1194       78      944         25725            1          debit
# 1204      1205       78      970         25725            1    credit_card
# 1259      1260       78      775         77175            3    credit_card
# 1384      1385       78      867         25725            1           cash
# ...

# %% [markdown]
# # Observation -
#
# 1. Shop 78 has 0 orders under 400 per pair of shoes
# 2. Shop 78 has 46 orders priced at 25,725 per pair of shoes

# %%
len(normal_orders[normal_orders['shop_id']==78]), len(outlier_orders[outlier_orders['shop_id']==78])
# Out:
# (0, 46)

# %% [markdown]
# Creating a final dataframe by removing these outlier values

# %%
df = df[df['user_id']!=607]
df = df[df['shop_id']!=78]
df
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0            1       53      746           224            2           cash
# 1            2       92      925            90            1           cash
# 2            3       44      861           144            1           cash
# 3            4       18      935           156            1    credit_card
# 4            5       18      883           156            1    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4995      4996       73      993           330            2          debit
# 4996      4997       48      789           234            2           cash
# 4997      4998       56      867           351            3           cash
# 4998      4999       60      825           354            2    credit_card
# 4999      5000       44      734           288            2          debit
#
#                created_at
# 0     2017-03-13 12:36:56
# ...

# %%
df['order_amount'].mean(), df['order_amount'].median()
# Out:
# (302.58051448247926, 284.0)

# %% [markdown]
# # Detailed Answers:
#
# # Q1. Think about what could be going wrong with our calculation.
#
# Answer:
#
# On performing basic exploratory data analysis came to know that there are outliers persent which are observations that lie on an abnormal distance from other values in a random sample from a population. After writing filtering code on the dataset user ID 607 anf Shop ID 78 were found to have some suspicious activity going on and were the outliers in the dataset. This was contributing to the errors in the overall calculations.
#
# # Q2. What metric would you report for this dataset?
#
# Answer:
#
# The metric to be used for this dataset would be a 'Median Order Value' since there are outliers present in our data-set. But on dropping the outliers 'Mean Order Value' can be used
#
#
# # Q3. What is its value?
#
# Answer:
#
# 284.0 (Median Order Value)
#
# After removing the outliers,
#
# 302.58 - Mean Order Value
